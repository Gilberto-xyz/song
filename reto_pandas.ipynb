# %%
import pandas as pd

# %%
data =  pd.read_csv('songs2018.csv')
data.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
filtro = data[['name','energy','artists','danceability']]
filtro.sort_values(by=['danceability'], ascending=False)
# Out:
#                                       name  energy        artists  \
# 91                              Yes Indeed   0.346       Lil Baby
# 55  FEFE (feat. Nicki Minaj & Murda Beatz)   0.387        6ix9ine
# 19                Look Alive (feat. Drake)   0.581     BlocBoy JB
# 18                               Moonlight   0.537   XXXTENTACION
# 61                                 Nonstop   0.412          Drake
# ..                                     ...     ...            ...
# 11                            Lucid Dreams   0.566     Juice WRLD
# 49                        Call Out My Name   0.598     The Weeknd
# 80                    lovely (with Khalid)   0.296  Billie Eilish
# 93                              This Is Me   0.704   Keala Settle
# 98             Dusk Till Dawn - Radio Edit   0.437           ZAYN
#
#     danceability
# 91         0.964
# 55         0.931
# 19         0.922
# 18         0.921
# 61         0.912
# ..           ...
# 11         0.511
# 49         0.489
# ...
